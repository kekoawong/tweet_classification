# %%
import pandas as pd

# import first representative tweet dataset
rep_tweets_df = pd.read_csv("../datasets/ExtractedTweets.csv")
rep_tweets_df
# Out:
#             Party         Handle  \
# 0        Democrat  RepDarrenSoto
# 1        Democrat  RepDarrenSoto
# 2        Democrat  RepDarrenSoto
# 3        Democrat  RepDarrenSoto
# 4        Democrat  RepDarrenSoto
# ...           ...            ...
# 86455  Republican    RepTomPrice
# 86456  Republican    RepTomPrice
# 86457  Republican    RepTomPrice
# 86458  Republican    RepTomPrice
# 86459  Republican    RepTomPrice
#
#                                                    Tweet
# 0      Today, Senate Dems vote to #SaveTheInternet. P...
# 1      RT @WinterHavenSun: Winter Haven resident / Al...
# 2      RT @NBCLatino: .@RepDarrenSoto noted that Hurr...
# 3      RT @NALCABPolicy: Meeting with @RepDarrenSoto ...
# 4      RT @Vegalteno: Hurricane season starts on June...
# ...                                                  ...
# 86455  Check out my op-ed on need for End Executive O...
# 86456  Yesterday, Betty &amp; I had a great time lear...
# ...

# %%
# import second trump/clinton dataset
candidate_tweets_df = pd.read_csv("../datasets/tweets.csv")
candidate_tweets_df
# Out:
#                       id           handle  \
# 0     780925634159796224   HillaryClinton
# 1     780916180899037184   HillaryClinton
# 2     780911564857761793   HillaryClinton
# 3     780907038650068994   HillaryClinton
# 4     780897419462602752   HillaryClinton
# ...                  ...              ...
# 6439  684219579548041218  realDonaldTrump
# 6440  684218836569206784  realDonaldTrump
# 6441  684218305100525569  realDonaldTrump
# 6442  684217554861199360  realDonaldTrump
# 6443  684216973815844866  realDonaldTrump
#
#                                                    text  is_retweet  \
# 0     The question in this election: Who can put the...       False
# 1     Last night, Donald Trump said not paying taxes...        True
# 2     Couldn't be more proud of @HillaryClinton. Her...        True
# 3     If we stand together, there's nothing we can't...       False
# 4     Both candidates were asked about how they'd co...       False
# ...

# %%
# clean the datasets
# store in data object as {Democrat: { user_handle: { tweetID: [text, [hashtags], [account_tags], boolean_Retweet] } }

# %%
# separate into training data
