# %%
import pandas as pd
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing
from sklearn import metrics
from sklearn.model_selection import train_test_split
import pickle
import graphviz

le = preprocessing.LabelEncoder()

# Get data, separate into features and labels
with open('../data/feature_vectors.obj', 'rb') as testing_file:
    data = pickle.load(testing_file)


data_df = pd.DataFrame.from_records(data, columns=["Party", "Tweet", "sentiment", "language", "dot_product", "vector", "is_retweet", "length_tweet", "num_hashtags", "num_mentions"])
data_df
# Out:
#             Party                                              Tweet  \
# 0        Democrat  Today, Senate Dems vote to #SaveTheInternet. P...
# 1        Democrat  RT @WinterHavenSun: Winter Haven resident / Al...
# 2        Democrat  RT @NBCLatino: .@RepDarrenSoto noted that Hurr...
# 3        Democrat  RT @NALCABPolicy: Meeting with @RepDarrenSoto ...
# 4        Democrat  RT @EmgageActionFL: Thank you to all who came ...
# ...           ...                                                ...
# 72620  Republican  What a scary statistic! Americans are working ...
# 72621    Democrat  I urge @EPAScottPruitt to resign because of hi...
# 72622    Democrat  Awesome! Also hope @Wheeling_Cats will check o...
# 72623    Democrat  RT @CNN: Rep. Adam Schiff, the top Democrat on...
# 72624  Republican  Our #WestTexas #energy fuels our economy and i...
#
#        sentiment language  dot_product  \
# 0       1.660000       en    27.835464
# 1       1.420000       en    -6.018233
# 2       1.240000       en    11.033403
# 3       1.720000       en    -0.447955
# 4       1.733333       en    26.004461
# ...          ...      ...          ...
# 72620   1.540000       en    19.692049
# 72621   1.286667       en    40.250832
# 72622   1.686667       en    16.865290
# 72623   1.540000       en     7.000402
# 72624   1.080000       en    25.831879
#
#                                                   vector  is_retweet  \
# 0      [-0.03105460652295733, 0.3615999109315453, 0.3...       False
# 1      [-0.05827691550621239, 0.2105472266111974, -0....        True
# 2      [0.2234409597585909, 0.1639013930107467, 0.352...        True
# 3      [-0.24786693104397273, 0.4860032578581013, -0....        True
# 4      [0.20108230298446017, 0.02912711470038687, -0....        True
# ...                                                  ...         ...
# 72620  [0.40658389572308806, -0.037907039832134615, 0...        True
# 72621  [0.39530073582068326, 0.1305930108967459, 0.43...       False
# 72622  [-0.030624291015556082, 0.3155437790628639, 0....       False
# 72623  [0.19569792719232737, 0.05175906507195549, 0.3...        True
# 72624  [0.0611736355949688, 0.47917420328667504, 0.15...       False
#
#        length_tweet  num_hashtags  num_mentions
# 0               139             2             0
# 1               140             0             2
# 2               140             0             2
# 3               140             1             3
# 4               139             0             1
# ...             ...           ...           ...
# 72620           123             0             0
# 72621           143             0             1
# 72622           140             1             1
# 72623           140             0             1
# 72624           136             2             0
#
# [72625 rows x 10 columns]

# %% [markdown]
# #### Encode the data

# %%
data_encoded = data_df.copy()
data_encoded["Party"] = le.fit_transform(data_encoded["Party"])
data_encoded["Retweet"] = le.fit_transform(data_encoded["is_retweet"])
data_encoded["language"] = le.fit_transform(data_encoded["language"])
data_encoded
# Out:
#        Party                                              Tweet  sentiment  \
# 0          0  Today, Senate Dems vote to #SaveTheInternet. P...   1.660000
# 1          0  RT @WinterHavenSun: Winter Haven resident / Al...   1.420000
# 2          0  RT @NBCLatino: .@RepDarrenSoto noted that Hurr...   1.240000
# 3          0  RT @NALCABPolicy: Meeting with @RepDarrenSoto ...   1.720000
# 4          0  RT @EmgageActionFL: Thank you to all who came ...   1.733333
# ...      ...                                                ...        ...
# 72620      1  What a scary statistic! Americans are working ...   1.540000
# 72621      0  I urge @EPAScottPruitt to resign because of hi...   1.286667
# 72622      0  Awesome! Also hope @Wheeling_Cats will check o...   1.686667
# 72623      0  RT @CNN: Rep. Adam Schiff, the top Democrat on...   1.540000
# 72624      1  Our #WestTexas #energy fuels our economy and i...   1.080000
#
#        language  dot_product  \
# 0             0    27.835464
# 1             0    -6.018233
# 2             0    11.033403
# 3             0    -0.447955
# 4             0    26.004461
# ...         ...          ...
# 72620         0    19.692049
# 72621         0    40.250832
# 72622         0    16.865290
# 72623         0     7.000402
# 72624         0    25.831879
#
#                                                   vector  is_retweet  \
# 0      [-0.03105460652295733, 0.3615999109315453, 0.3...       False
# 1      [-0.05827691550621239, 0.2105472266111974, -0....        True
# 2      [0.2234409597585909, 0.1639013930107467, 0.352...        True
# 3      [-0.24786693104397273, 0.4860032578581013, -0....        True
# 4      [0.20108230298446017, 0.02912711470038687, -0....        True
# ...                                                  ...         ...
# 72620  [0.40658389572308806, -0.037907039832134615, 0...        True
# 72621  [0.39530073582068326, 0.1305930108967459, 0.43...       False
# 72622  [-0.030624291015556082, 0.3155437790628639, 0....       False
# 72623  [0.19569792719232737, 0.05175906507195549, 0.3...        True
# 72624  [0.0611736355949688, 0.47917420328667504, 0.15...       False
#
#        length_tweet  num_hashtags  num_mentions  Retweet
# 0               139             2             0        0
# 1               140             0             2        1
# 2               140             0             2        1
# 3               140             1             3        1
# 4               139             0             1        1
# ...             ...           ...           ...      ...
# 72620           123             0             0        1
# 72621           143             0             1        0
# 72622           140             1             1        0
# 72623           140             0             1        1
# 72624           136             2             0        0
#
# [72625 rows x 11 columns]

# %% [markdown]
# #### Split into testing and training data

# %%
train_df, test_df = train_test_split(data_encoded, test_size=0.2, random_state=42, shuffle=True)

# %%
train_df
# Out:
#        Party                                              Tweet  sentiment  \
# 56059      0  Bringing on 50,000 new computer science teache...   2.015000
# 32292      1  Xavier bravely saved another young man's life ...   2.205000
# 13270      0  @openletterbot @catialada I completely share y...   2.506667
# 23351      0  Today is the last day of #OpenEnrollment so do...   1.404000
# 10297      0  In Northwest Oregon, we celebrate the mighty C...   1.385000
# ...      ...                                                ...        ...
# 37194      1  RT @NFIB: Reports of improved earnings reached...   1.765000
# 6265       0  Yesterday I sat down with our Washington, D.C....   1.340000
# 54886      0  The week after 9/11, George W. Bush went to a ...   1.410000
# 860        0  Good morning! Join me at 7:40am when Rep. Pete...   1.664000
# 15795      0  Yesterday I sat down with @JoaquinCastrotx, Sa...   0.993333
#
#        language  dot_product  \
# 56059         0    12.321572
# 32292         0     8.478309
# 13270         0     5.328323
# 23351         0    34.265717
# 10297         0    15.758232
# ...         ...          ...
# 37194         0    16.487526
# 6265          0    25.976894
# 54886         0    34.536224
# 860           0    18.480972
# 15795         0    -0.536514
#
#                                                   vector  is_retweet  \
# 56059  [0.23241318799045985, -0.17500857054517382, 0....        True
# 32292  [-0.07581671410343915, 0.4409067284748289, 0.0...       False
# 13270  [-0.0825056354078697, -0.37020410426703165, -0...       False
# 23351  [-0.04632562853088018, 0.32448489299611083, 0....       False
# 10297  [-0.6186065866957051, 0.2719376258646662, -0.0...       False
# ...                                                  ...         ...
# 37194  [-0.13487441587335525, 0.15597572873002719, -0...        True
# 6265   [-0.017384540291232042, 0.07391470867275984, 0...       False
# 54886  [-0.01194908512091164, -0.041027962788463324, ...       False
# 860    [0.02011150051629329, 0.5170896550322936, 0.26...       False
# 15795  [0.1303271230754035, 0.09296986249319161, -0.3...       False
#
#        length_tweet  num_hashtags  num_mentions  Retweet
# 56059           129             0             0        1
# 32292           139             0             0        0
# 13270           140             0             2        0
# 23351           139             1             0        0
# 10297           140             0             0        0
# ...             ...           ...           ...      ...
# 37194           140             0             2        1
# 6265            140             0             0        0
# 54886           136             0             0        0
# 860             140             0             0        0
# 15795           140             0             2        0
#
# [58100 rows x 11 columns]

# %%
test_df
# Out:
#        Party                                              Tweet  sentiment  \
# 61018      1  RT @93wibc: @RepJimBanks discusses the Preside...   1.340000
# 20416      0  RT @HomelandDems: ICYMI - Ranking Members @Ben...   1.030000
# 43595      1  Congressman Griffith enjoyed watching last nig...   2.073333
# 26231      0  President Trump is pushing our country toward ...   2.400000
# 71634      0  Seeing the massive crowds excited to hear Mich...   0.940000
# ...      ...                                                ...        ...
# 1281       0  #HappyMothersDay to all the moms and honorary ...   1.995000
# 45443      1  UPDATE: The hearing will reconvene at the end ...   0.886667
# 65141      0  Nurses are at our sides through some of the be...   2.120000
# 33239      1  St. Nickolas, Constantine, &amp; Helen Greek O...   1.073333
# 35653      1  I added a video to a @YouTube playlist http://...   1.626667
#
#        language  dot_product  \
# 61018         0     3.502597
# 20416         0     1.593524
# 43595         0     2.393675
# 26231         0    19.899752
# 71634         0    15.474901
# ...         ...          ...
# 1281          0    40.250832
# 45443         0    13.317113
# 65141         0    11.858605
# 33239         0    -3.717728
# 35653         0    23.862463
#
#                                                   vector  is_retweet  \
# 61018  [0.4720800658396911, 0.2966051958537719, -0.26...        True
# 20416  [0.21594631337211467, 0.08835732201441715, -0....        True
# 43595  [-0.12946978604304604, -0.11951498006237671, 0...       False
# 26231  [0.07013527980689105, 0.27208977884129126, 0.2...       False
# 71634  [0.06325251617045069, -0.1680865640846605, 0.2...       False
# ...                                                  ...         ...
# 1281   [0.09649022076985148, 0.31389840979989003, 0.0...       False
# 45443  [0.31388538908777264, 0.029376562393736094, 0....       False
# 65141  [-0.12075630656568137, 0.25943277220335403, 0....       False
# 33239  [-0.6164123144908444, 0.3801139269600071, 0.03...       False
# 35653  [-0.2945473807048984, -0.25406910963647533, -0...       False
#
#        length_tweet  num_hashtags  num_mentions  Retweet
# 61018           140             0             3        1
# 20416           144             0             3        1
# 43595           135             0             0        0
# 26231           140             0             0        0
# 71634           143             1             0        0
# ...             ...           ...           ...      ...
# 1281            139             1             0        0
# 45443            73             0             0        0
# 65141           140             1             0        0
# 33239           144             1             0        0
# 35653            91             0             1        0
#
# [14525 rows x 11 columns]

# %% [markdown]
# #### Get features of testing and training set

# %%
# training set
x_train = train_df[["sentiment", "language", "dot_product", "is_retweet"]]
y_train = train_df[["Party"]]

# testing set
x_test = test_df[["sentiment", "language", "dot_product", "is_retweet"]]
y_test = test_df[["Party"]]

# %% [markdown]
# #### Build ID3 tree using entropy

# %%
clf_entropy = tree.DecisionTreeClassifier(criterion="entropy")
clf_entropy.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %% [markdown]
# #### Display Tree

# %%
dot_data_entropy = tree.export_graphviz(clf_entropy, out_file=None,
                                feature_names=["sentiment", "language", "dot_product", "is_retweet"],
                                class_names=["Democrat", "Republican"],
                                filled=True, rounded=True,
                                special_characters=True)  
graph_entropy = graphviz.Source(dot_data_entropy)
graph_entropy
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-97b7966d7887> in <module>
#       5                                 special_characters=True)
#       6 graph_entropy = graphviz.Source(dot_data_entropy)
# ----> 7 graph_entropy
#
# /escnfs/home/pbui/pub/pkgsrc-2019Q4/lib/python3.8/site-packages/IPython/core/displayhook.py in __call__(self, result)
#     260             self.start_displayhook()
#     261             self.write_output_prompt()
# --> 262             format_dict, md_dict = self.compute_format_data(result)
#     263             self.update_user_ns(result)
#     264             self.fill_exec_result(result)
#
# /escnfs/home/pbui/pub/pkgsrc-2019Q4/lib/python3.8/site-packages/IPython/core/displayhook.py in compute_format_data(self, result)
#     149
#     150         """
# --> 151         return self.shell.display_formatter.format(result)
#     152
#     153     # This can be set to True by the write_output_prompt method in a subclass
#
# /escnfs/home/pbui/pub/pkgsrc-2019Q4/lib/python3.8/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# </escnfs/home/pbui/pub/pkgsrc-2019Q4/lib/python3.8/site-packages/decorator.py:decorator-gen-9> in __call__(self, obj)
#
# /escnfs/home/pbui/pub/pkgsrc-2019Q4/lib/python3.8/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /escnfs/home/pbui/pub/pkgsrc-2019Q4/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/.local/lib/python3.8/site-packages/graphviz/files.py in _repr_svg_(self)
#     111
#     112     def _repr_svg_(self):
# --> 113         return self.pipe(format='svg').decode(self._encoding)
#     114
#     115     def pipe(self, format=None, renderer=None, formatter=None, quiet=False):
#
# ~/.local/lib/python3.8/site-packages/graphviz/files.py in pipe(self, format, renderer, formatter, quiet)
#     134         data = text_type(self.source).encode(self._encoding)
#     135
# --> 136         out = backend.pipe(self._engine, format, data,
#     137                            renderer=renderer, formatter=formatter,
#     138                            quiet=quiet)
#
# ~/.local/lib/python3.8/site-packages/graphviz/backend.py in pipe(engine, format, data, renderer, formatter, quiet)
#     242     """
#     243     cmd, _ = command(engine, format, None, renderer, formatter)
# --> 244     out, _ = run(cmd, input=data, capture_output=True, check=True, quiet=quiet)
#     245     return out
#     246
#
# ~/.local/lib/python3.8/site-packages/graphviz/backend.py in run(cmd, input, capture_output, check, encoding, quiet, **kwargs)
#     169             raise
#     170
# --> 171     out, err = proc.communicate(input)
#     172
#     173     if not quiet and err:
#
# /escnfs/home/pbui/pub/pkgsrc-2019Q4/lib/python3.8/subprocess.py in communicate(self, input, timeout)
#    1022
#    1023             try:
# -> 1024                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1025             except KeyboardInterrupt:
#    1026                 # https://bugs.python.org/issue25942
#
# /escnfs/home/pbui/pub/pkgsrc-2019Q4/lib/python3.8/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1864                             'failed to raise TimeoutExpired.')
#    1865
# -> 1866                     ready = selector.select(timeout)
#    1867                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    1868
#
# /escnfs/home/pbui/pub/pkgsrc-2019Q4/lib/python3.8/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
# Print Accuracy
y_pred_entropy = clf_entropy.predict(x_test)
print("ID3 Tree Results")
print("Predicted:", y_pred_entropy)
print("Accuracy:", metrics.accuracy_score(y_test, y_pred_entropy))
# Out:
# ID3 Tree Results
# Predicted: [0 0 1 ... 1 1 0]
# Accuracy: 0.5275043029259897

# %% [markdown]
# #### Build tree using Gini

# %%
clf_gini = tree.DecisionTreeClassifier()
clf_gini.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# #### Display Gini Tree

# %%
dot_data_gini = tree.export_graphviz(clf_gini, out_file=None,
                                feature_names=["sentiment", "language", "dot_product", "is_retweet"],
                                class_names=["Democrat", "Republican"],
                                filled=True, rounded=True,
                                special_characters=True)  
graph_gini = graphviz.Source(dot_data_gini)

# %%
# Print Accuracy
y_pred_gini = clf_gini.predict(x_test)
print("Gini Tree Results")
print("Predicted:", y_pred_gini)
print("Accuracy:", metrics.accuracy_score(y_test, y_pred_gini))
# Out:
# Gini Tree Results
# Predicted: [0 0 1 ... 1 1 0]
# Accuracy: 0.5344578313253012

# %%
# Random Forest
clf_rf = RandomForestClassifier(max_depth=7, min_samples_split=0.1, min_samples_leaf=0.05)
clf_rf.fit(x_train, y_train.values.ravel())
y_pred_rf = clf_rf.predict(x_test)
print("Predicted:", y_pred_rf)
print("Accuracy:", metrics.accuracy_score(y_test, y_pred_rf))
# Out:
# Predicted: [1 0 1 ... 1 0 1]
# Accuracy: 0.5224784853700516
