# %%
import json
import pickle
from nltk.stem.snowball import SnowballStemmer
from langdetect import detect

stemmer_en = SnowballStemmer("english")
stemmer_sp = SnowballStemmer("spanish")

with open('../data/training_data.obj', 'rb') as training_file:
    training_data = pickle.load(training_file)
with open('../data/sentiment_words_en.json') as sent_words:
    sentiment_words_en = json.load(sent_words)
with open('../data/sentiment_words_es.json') as sent_words:
    sentiment_words_sp = json.load(sent_words)

# %% [markdown]
# ### Problems
# Spanish vs English
# Need to average out sentiment score, could take average of highest scoring words
#
# #### Features
# Sentiment, is english, tf_idf of hashtags?, party_of_tagged_users multiplied by sentiment?

# %% [markdown]
# #### Get rough sentiment of tweet

# %%
tweets = []
for tweet in training_data['tweets']:
    
    score = 0
    tweet_words = tweet[1].lower()
    
    try:
        lang = detect(tweet_words)
    except:
        print('LangDetectException')
        print(tweet_words)

    for word in tweet_words.split():
        # if spanish
        if lang == 'es':
            root_word = stemmer_sp.stem(word)
            if root_word in sentiment_words_sp:
                score += sentiment_words_sp[root_word]
        elif lang == 'en':
            root_word = stemmer_en.stem(word)
            if root_word in sentiment_words_en:
                score += sentiment_words_en[root_word]
    tweets.append([tweet[6], score, lang])
tweets
# Out:
# LangDetectException
#
# LangDetectException
#
# LangDetectException
# 6210102
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#  0
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
#
# LangDetectException
