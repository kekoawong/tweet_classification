# %% [markdown]
# # Load Data for Viewing
# ### This notebook will load the processed data into a pandas dataframe for viewing

# %% [markdown]
# #### Import libraries and load objects

# %%
import pandas as pd
import pickle

with open('../data/testing_data_ht_ment.obj', 'rb') as testing_file:
    testing_data = pickle.load(testing_file)

with open('../data/training_data.obj', 'rb') as training_file:
    training_data = pickle.load(training_file)

# %%
tr_data_df = pd.DataFrame.from_records(training_data['tweets'], columns=['Party', 'Tweet_Text', 'Hashtags', 'Mentions', 'Retweet', 'Handle'])
tr_data_df
# Out:
#             Party                                         Tweet_Text  \
# 0        Democrat  Today Senate Dems vote to  Proud to support si...
# 1        Democrat    noted that Hurricane Maria has left approxim...
# 2        Democrat   Meeting with  Thanks for taking the time to m...
# 3        Democrat   Hurricane season starts on June st Puerto Ric...
# 4        Democrat   Thank you to all who came out to our Orlando ...
# ...           ...                                                ...
# 73801  Republican   Whats wrong with showing Morocco Nothing It i...
# 73802  Republican  I dont know  to best of my knowledge havent pl...
# 73803  Republican  Wow circulation in NH has dropped from to arou...
# 73804  Republican   My Facebook Groups are all voting TRUMP 4000 ...
# 73805  Republican   Minimizing dependency on China is crucialOnly...
#
#                                  Hashtags  \
# 0      [#SaveTheInternet, #NetNeutrality]
# 1                                      []
# 2                     [#NALCABPolicy2018]
# 3                                      []
# 4                                      []
# ...                                   ...
# 73801                                  []
# 73802                                  []
# 73803                                  []
# 73804                                  []
# 73805                                  []
#
#                                                 Mentions  Retweet  \
# 0                                                     []    False
# 1                           [@NBCLatino, @RepDarrenSoto]     True
# 2         [@NALCABPolicy, @RepDarrenSoto, @LatinoLeader]     True
# 3      [@Vegalteno, @Pwr4PuertoRico, @RepDarrenSoto, ...     True
# 4                                      [@EmgageActionFL]     True
# ...                                                  ...      ...
# 73801                              [@Lucky5713, @NewDay]    False
# 73802                                  [@SamuelLJackson]    False
# 73803                                     [@UnionLeader]    False
# 73804               [@lilredfrmkokomo, @realDonaldTrump]    False
# 73805  [@iLoveiDevices, @EdwinRo47796972, @happyjack2...    False
#
#                 Handle
# 0        RepDarrenSoto
# 1        RepDarrenSoto
# 2        RepDarrenSoto
# 3        RepDarrenSoto
# 4        RepDarrenSoto
# ...                ...
# 73801  realDonaldTrump
# 73802  realDonaldTrump
# 73803  realDonaldTrump
# 73804  realDonaldTrump
# 73805  realDonaldTrump
#
# [73806 rows x 6 columns]

# %%
test_data_df = pd.DataFrame.from_records(testing_data['tweets'], columns=['Party', 'Tweet_Text', 'Hashtags', 'Mentions', 'Retweet', 'Handle'])
test_data_df
# Out:
#             Party                                         Tweet_Text  \
# 0        Democrat  Mike Pompeo is manifestly unfit to be Secretar...
# 1        Democrat  Today is the anniversary of the first Freedom ...
# 2        Democrat  Today we observe Human Rights Day.  Please tak...
# 3        Democrat  The President promised Mexico would pay for th...
# 4      Republican  Be safe out there! Visit @WDNR for more info: ...
# ...           ...                                                ...
# 18566    Democrat  Have a good luck charm in the green room, gett...
# 18567  Republican  On #TeacherAppreciationDay and every day we ar...
# 18568  Republican   @jedelmanUSHMM: I'm so thrilled for all who w...
# 18569    Democrat  #CongressAtYourCompany visit to @KCP_tweets – ...
# 18570  Republican   @HouseGOP: .@POTUS: We are incredibly gratefu...
#
#                         Hashtags                   Mentions  Retweet  \
# 0                             []                         []    False
# 1                             []                         []    False
# 2                             []                         []    False
# 3                        [#sotu]                         []    False
# 4                             []                    [@WDNR]    False
# ...                          ...                        ...      ...
# 18566                   [#AMJoy]  [@JoyAnnReid, @amjoyshow]    False
# 18567  [#TeacherAppreciationDay]                         []    False
# 18568                         []           [@jedelmanUSHMM]     True
# 18569   [#CongressAtYourCompany]              [@KCP_tweets]    False
# 18570                         []        [@HouseGOP, @POTUS]     True
#
#                 Handle
# 0      BettyMcCollum04
# 1       RepJohnDelaney
# 2          BradSherman
# 3       USRepRickNolan
# 4         RepSeanDuffy
# ...                ...
# 18566    RepJoeKennedy
# 18567      EdWorkforce
# 18568    RepKevinYoder
# 18569  RepCharlieCrist
# 18570   JimPressOffice
#
# [18571 rows x 6 columns]
